# %%
# Convertir imagen a negro, para utilizar el MaxPooling()
import cv2
import os
import matplotlib.pyplot as plt

# Directorio de las imágenes originales
directorio_original = "spiral/testing/parkinson/"
directorio_destino = "spirals/testing/test_parkinson_negro_spiral"
os.makedirs(directorio_destino, exist_ok=True)

# Iterar sobre las imágenes originales
for filename in os.listdir(directorio_original):
    ruta_original = os.path.join(directorio_original, filename)
    imagen_original = cv2.imread(ruta_original)

    # Convertir la imagen a escala de grises
    imagen_gris = cv2.cvtColor(imagen_original, cv2.COLOR_BGR2GRAY)

    # Invertir colores en escala de grises
    imagen_invertida = cv2.bitwise_not(imagen_gris)

    # Nombre de la nueva imagen invertida
    nombre_nueva_imagen = f"{filename[:-4]}_invertida.png"
    ruta_nueva_imagen = os.path.join(directorio_destino, nombre_nueva_imagen)

    # Guardar la imagen invertida
    cv2.imwrite(ruta_nueva_imagen, imagen_invertida)

# Mostrar la primera imagen original e invertida
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_original, os.listdir(directorio_original)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Original")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_destino, os.listdir(directorio_destino)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Invertida")

plt.show()

# %%
# Convertir imagen a negro, para utilizar el MaxPooling()
import cv2
import os
import matplotlib.pyplot as plt

# Directorio de las imágenes originales
directorio_original = "spiral/testing/healthy/"
directorio_destino = "spirals/testing/test_healthy_negro_spiral"
os.makedirs(directorio_destino, exist_ok=True)

# Iterar sobre las imágenes originales
for filename in os.listdir(directorio_original):
    ruta_original = os.path.join(directorio_original, filename)
    imagen_original = cv2.imread(ruta_original)

    # Convertir la imagen a escala de grises
    imagen_gris = cv2.cvtColor(imagen_original, cv2.COLOR_BGR2GRAY)

    # Invertir colores en escala de grises
    imagen_invertida = cv2.bitwise_not(imagen_gris)

    # Nombre de la nueva imagen invertida
    nombre_nueva_imagen = f"{filename[:-4]}_invertida.png"
    ruta_nueva_imagen = os.path.join(directorio_destino, nombre_nueva_imagen)

    # Guardar la imagen invertida
    cv2.imwrite(ruta_nueva_imagen, imagen_invertida)

# Mostrar la primera imagen original e invertida
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_original, os.listdir(directorio_original)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Original")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_destino, os.listdir(directorio_destino)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Invertida")

plt.show()

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spiral2/testing/test_healthy_negro_spiral"  
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen horizontalmente
    imagen_girada = cv2.flip(imagen, 1)

    # Guardar la imagen girada
    ruta_imagen_girada = os.path.join(directorio, f"{archivo[:-4]}_girada.png")
    cv2.imwrite(ruta_imagen_girada, imagen_girada)
    
print("Aumentación horizonal de datos completada.")
# Out:
# Aumentación horizonal de datos completada.

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spirals/testing/test_parkinson_negro_spiral"  
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen horizontalmente
    imagen_girada = cv2.flip(imagen, 1)

    # Guardar la imagen girada
    ruta_imagen_girada = os.path.join(directorio, f"{archivo[:-4]}_girada.png")
    cv2.imwrite(ruta_imagen_girada, imagen_girada)
    
print("Aumentación horizonal de datos completada.")
# Out:
# Aumentación horizonal de datos completada.

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spirals/testing/test_parkinson_negro_spiral"  # Cambiar por la ruta correcta
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen de arriba a abajo
    imagen_girada_abajo = cv2.flip(imagen, 0)

    # Guardar la imagen girada en el mismo directorio con un nuevo nombre
    ruta_imagen_girada_abajo = os.path.join(directorio, f"{archivo[:-4]}_girada_abajo.png")
    cv2.imwrite(ruta_imagen_girada_abajo, imagen_girada_abajo)

print('Aumentación vertical de datos completada.')
# Out:
# Aumentación vertical de datos completada.

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spirals/testing/test_healthy_negro_spiral"  # Cambiar por la ruta correcta
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen de arriba a abajo
    imagen_girada_abajo = cv2.flip(imagen, 0)

    # Guardar la imagen girada en el mismo directorio con un nuevo nombre
    ruta_imagen_girada_abajo = os.path.join(directorio, f"{archivo[:-4]}_girada_abajo.png")
    cv2.imwrite(ruta_imagen_girada_abajo, imagen_girada_abajo)

print('Aumentación vertical de datos completada.')
# Out:
# Aumentación vertical de datos completada.

# %%
import cv2
import os
import numpy as np

# Directorio de las imágenes
directorio = "spirals/testing/test_healthy_negro_spiral" 
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Generar un factor aleatorio para el brillo entre 1.5 y 2.0
    factor_brillo = np.random.uniform(1.5, 2.0)

    # Aumentar el brillo multiplicando los valores de píxeles por el factor
    imagen_brillo_aumentado = np.clip(imagen * factor_brillo, 0, 255).astype(np.uint8)

    # Guardar la imagen con brillo aumentado
    ruta_imagen_brillo_aumentado = os.path.join(directorio, f"{archivo[:-4]}_brillo_aumentado.png")
    cv2.imwrite(ruta_imagen_brillo_aumentado, imagen_brillo_aumentado)

print("Aumentación brillo de datos completada.")
# Out:
# Aumentación brillo de datos completada.

# %%
import cv2
import os
import numpy as np

# Directorio de las imágenes
directorio = "spirals/testing/test_parkinson_negro_spiral" 
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Generar un factor aleatorio para el brillo entre 1.5 y 2.0
    factor_brillo = np.random.uniform(1.5, 2.0)

    # Aumentar el brillo multiplicando los valores de píxeles por el factor
    imagen_brillo_aumentado = np.clip(imagen * factor_brillo, 0, 255).astype(np.uint8)

    # Guardar la imagen con brillo aumentado
    ruta_imagen_brillo_aumentado = os.path.join(directorio, f"{archivo[:-4]}_brillo_aumentado.png")
    cv2.imwrite(ruta_imagen_brillo_aumentado, imagen_brillo_aumentado)

print("Aumentación brillo de datos completada.")
# Out:
# Aumentación brillo de datos completada.

# %%
# Convertir imagen a negro, para utilizar el MaxPooling()
import cv2
import os
import matplotlib.pyplot as plt

# Directorio de las imágenes originales
directorio_original = "spiral/training/healthy/"
directorio_destino = "spirals/training/training_healthy_negro_spiral"
os.makedirs(directorio_destino, exist_ok=True)

# Iterar sobre las imágenes originales
for filename in os.listdir(directorio_original):
    ruta_original = os.path.join(directorio_original, filename)
    imagen_original = cv2.imread(ruta_original)

    # Convertir la imagen a escala de grises
    imagen_gris = cv2.cvtColor(imagen_original, cv2.COLOR_BGR2GRAY)

    # Invertir colores en escala de grises
    imagen_invertida = cv2.bitwise_not(imagen_gris)

    # Nombre de la nueva imagen invertida
    nombre_nueva_imagen = f"{filename[:-4]}_invertida.png"
    ruta_nueva_imagen = os.path.join(directorio_destino, nombre_nueva_imagen)

    # Guardar la imagen invertida
    cv2.imwrite(ruta_nueva_imagen, imagen_invertida)

# Mostrar la primera imagen original e invertida
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_original, os.listdir(directorio_original)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Original")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_destino, os.listdir(directorio_destino)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Invertida")

plt.show()

# %%
# Convertir imagen a negro, para utilizar el MaxPooling()
import cv2
import os
import matplotlib.pyplot as plt

# Directorio de las imágenes originales
directorio_original = "spiral/training/parkinson/"
directorio_destino = "spirals/training/training_parkinson_negro_spiral"
os.makedirs(directorio_destino, exist_ok=True)

# Iterar sobre las imágenes originales
for filename in os.listdir(directorio_original):
    ruta_original = os.path.join(directorio_original, filename)
    imagen_original = cv2.imread(ruta_original)

    # Convertir la imagen a escala de grises
    imagen_gris = cv2.cvtColor(imagen_original, cv2.COLOR_BGR2GRAY)

    # Invertir colores en escala de grises
    imagen_invertida = cv2.bitwise_not(imagen_gris)

    # Nombre de la nueva imagen invertida
    nombre_nueva_imagen = f"{filename[:-4]}_invertida.png"
    ruta_nueva_imagen = os.path.join(directorio_destino, nombre_nueva_imagen)

    # Guardar la imagen invertida
    cv2.imwrite(ruta_nueva_imagen, imagen_invertida)

# Mostrar la primera imagen original e invertida
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_original, os.listdir(directorio_original)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Original")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(directorio_destino, os.listdir(directorio_destino)[0])), cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Primera Imagen Invertida")

plt.show()

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spirals/training/training_parkinson_negro_spiral"  
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen horizontalmente
    imagen_girada = cv2.flip(imagen, 1)

    # Guardar la imagen girada
    ruta_imagen_girada = os.path.join(directorio, f"{archivo[:-4]}_girada.png")
    cv2.imwrite(ruta_imagen_girada, imagen_girada)
    
print("Aumentación horizonal de datos completada.")
# Out:
# Aumentación horizonal de datos completada.

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spirals/training/training_healthy_negro_spiral"  
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen horizontalmente
    imagen_girada = cv2.flip(imagen, 1)

    # Guardar la imagen girada
    ruta_imagen_girada = os.path.join(directorio, f"{archivo[:-4]}_girada.png")
    cv2.imwrite(ruta_imagen_girada, imagen_girada)
    
print("Aumentación horizonal de datos completada.")
# Out:
# Aumentación horizonal de datos completada.

# %%
import cv2
import os
import numpy as np

# Directorio de las imágenes
directorio = "spirals/training/training_parkinson_negro_spiral" 
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Generar un factor aleatorio para el brillo entre 1.5 y 2.0
    factor_brillo = np.random.uniform(1.5, 2.0)

    # Aumentar el brillo multiplicando los valores de píxeles por el factor
    imagen_brillo_aumentado = np.clip(imagen * factor_brillo, 0, 255).astype(np.uint8)

    # Guardar la imagen con brillo aumentado
    ruta_imagen_brillo_aumentado = os.path.join(directorio, f"{archivo[:-4]}_brillo_aumentado.png")
    cv2.imwrite(ruta_imagen_brillo_aumentado, imagen_brillo_aumentado)

print("Aumentación brillo de datos completada.")
# Out:
# Aumentación brillo de datos completada.

# %%
import cv2
import os
import numpy as np

# Directorio de las imágenes
directorio = "spirals/training/training_healthy_negro_spiral" 
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Generar un factor aleatorio para el brillo entre 1.5 y 2.0
    factor_brillo = np.random.uniform(1.5, 2.0)

    # Aumentar el brillo multiplicando los valores de píxeles por el factor
    imagen_brillo_aumentado = np.clip(imagen * factor_brillo, 0, 255).astype(np.uint8)

    # Guardar la imagen con brillo aumentado
    ruta_imagen_brillo_aumentado = os.path.join(directorio, f"{archivo[:-4]}_brillo_aumentado.png")
    cv2.imwrite(ruta_imagen_brillo_aumentado, imagen_brillo_aumentado)

print("Aumentación brillo de datos completada.")
# Out:
# Aumentación brillo de datos completada.

# %%
import cv2
import os
import numpy as np

# Directorio de las imágenes
directorio = "spirals/training/training_healthy_negro_spiral" 
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Generar un factor aleatorio para el brillo entre 1.5 y 2.0
    factor_brillo = np.random.uniform(1.5, 2.0)

    # Aumentar el brillo multiplicando los valores de píxeles por el factor
    imagen_brillo_aumentado = np.clip(imagen * factor_brillo, 0, 255).astype(np.uint8)

    # Guardar la imagen con brillo aumentado
    ruta_imagen_brillo_aumentado = os.path.join(directorio, f"{archivo[:-4]}_brillo_aumentado.png")
    cv2.imwrite(ruta_imagen_brillo_aumentado, imagen_brillo_aumentado)

print("Aumentación brillo de datos completada.")
# Out:
# Aumentación brillo de datos completada.

# %%
import cv2
import os
import numpy as np

# Directorio de las imágenes
directorio = "spirals/training/training_parkinson_negro_spiral" 
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Generar un factor aleatorio para el brillo entre 1.5 y 2.0
    factor_brillo = np.random.uniform(1.5, 2.0)

    # Aumentar el brillo multiplicando los valores de píxeles por el factor
    imagen_brillo_aumentado = np.clip(imagen * factor_brillo, 0, 255).astype(np.uint8)

    # Guardar la imagen con brillo aumentado
    ruta_imagen_brillo_aumentado = os.path.join(directorio, f"{archivo[:-4]}_brillo_aumentado.png")
    cv2.imwrite(ruta_imagen_brillo_aumentado, imagen_brillo_aumentado)

print("Aumentación brillo de datos completada.")
# Out:
# Aumentación brillo de datos completada.

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spirals/training/training_parkinson_negro_spiral"  
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen de arriba a abajo
    imagen_girada_abajo = cv2.flip(imagen, 0)

    # Guardar la imagen girada en el mismo directorio con un nuevo nombre
    ruta_imagen_girada_abajo = os.path.join(directorio, f"{archivo[:-4]}_girada_abajo.png")
    cv2.imwrite(ruta_imagen_girada_abajo, imagen_girada_abajo)

print('Aumentación vertical de datos completada.')
# Out:
# Aumentación vertical de datos completada.

# %%
import cv2
import os

# Directorio de las imágenes
directorio = "spirals/training/training_healthy_negro_spiral"  
os.makedirs(directorio, exist_ok=True)

# Obtener la lista de archivos en el directorio
archivos = os.listdir(directorio)

# Iterar sobre las imágenes en el directorio
for archivo in archivos:
    ruta_imagen = os.path.join(directorio, archivo)

    # Leer la imagen
    imagen = cv2.imread(ruta_imagen)

    # Girar la imagen de arriba a abajo
    imagen_girada_abajo = cv2.flip(imagen, 0)

    # Guardar la imagen girada en el mismo directorio con un nuevo nombre
    ruta_imagen_girada_abajo = os.path.join(directorio, f"{archivo[:-4]}_girada_abajo.png")
    cv2.imwrite(ruta_imagen_girada_abajo, imagen_girada_abajo)

print('Aumentación vertical de datos completada.')
# Out:
# Aumentación vertical de datos completada.

# %%
# Aumentar Imágenes Training
import cv2
import os
import numpy as np
import shutil

# Directorio de las imágenes originales
directorio_original = "spirals/training/training_healthy_negro_spiral"
directorio_destino = "spirals/training/total_training_healthy_negro"
os.makedirs(directorio_destino, exist_ok=True)

# Número de ángulos para rotar la imagen (10 vueltas)
num_rotaciones_por_imagen = 10

# Iterar sobre las imágenes originales
for filename in os.listdir(directorio_original):
    ruta_original = os.path.join(directorio_original, filename)
    imagen_original = cv2.imread(ruta_original)

    # Iterar sobre las imágenes generadas y aplicar rotaciones personalizadas
    for i in range(num_rotaciones_por_imagen):
        # Ángulo de rotación en grados
        angulo = i * (360 / num_rotaciones_por_imagen)

        # Rotar la imagen usando OpenCV
        matriz_rotacion = cv2.getRotationMatrix2D((imagen_original.shape[1] // 2, imagen_original.shape[0] // 2), angulo, 1)
        imagen_rotada = cv2.warpAffine(imagen_original, matriz_rotacion, (imagen_original.shape[1], imagen_original.shape[0]))

        # Nombre de la nueva imagen aumentada
        nombre_nueva_imagen = f"{filename[:-4]}_rotada_{i}.png"
        ruta_nueva_imagen = os.path.join(directorio_destino, nombre_nueva_imagen)

        # Guardar la imagen aumentada
        cv2.imwrite(ruta_nueva_imagen, imagen_rotada)

shutil.rmtree(directorio_original)
print("Aumentación de datos completada.")
# Out:
# Aumentación de datos completada.

# %%
# Aumentar Imágenes Training
import cv2
import os
import numpy as np

# Directorio de las imágenes originales
directorio_original = "spirals/training/training_parkinson_negro_spiral"
directorio_destino = "spirals/training/total_training_parkinson_negro"
os.makedirs(directorio_destino, exist_ok=True)

# Número de ángulos para rotar la imagen (10 vueltas)
num_rotaciones_por_imagen = 10

# Iterar sobre las imágenes originales
for filename in os.listdir(directorio_original):
    ruta_original = os.path.join(directorio_original, filename)
    imagen_original = cv2.imread(ruta_original)

    # Iterar sobre las imágenes generadas y aplicar rotaciones personalizadas
    for i in range(num_rotaciones_por_imagen):
        # Ángulo de rotación en grados
        angulo = i * (360 / num_rotaciones_por_imagen)

        # Rotar la imagen usando OpenCV
        matriz_rotacion = cv2.getRotationMatrix2D((imagen_original.shape[1] // 2, imagen_original.shape[0] // 2), angulo, 1)
        imagen_rotada = cv2.warpAffine(imagen_original, matriz_rotacion, (imagen_original.shape[1], imagen_original.shape[0]))

        # Nombre de la nueva imagen aumentada
        nombre_nueva_imagen = f"{filename[:-4]}_rotada_{i}.png"
        ruta_nueva_imagen = os.path.join(directorio_destino, nombre_nueva_imagen)

        # Guardar la imagen aumentada
        cv2.imwrite(ruta_nueva_imagen, imagen_rotada)

shutil.rmtree(directorio_original)
print("Aumentación de datos completada.")
# Out:
# Aumentación de datos completada.

# %%
# Mirar este -> https://colab.research.google.com/drive/1DQc8a-WOTctenvoy5T0lWUXn47EuteCy?usp=sharing#scrollTo=BtEYnFkNyN_s
import pandas as pd
from PIL import Image
import pandas as pd
import os

carpeta = 'spirals/training'

# Lista para almacenar las rutas de los archivos
rutas_archivos = []

# Obtener la lista de archivos en la carpeta
for root, dirs, files in os.walk(carpeta):
    for file in files:
        # Añadir la ruta completa del archivo a la lista
        ruta_completa = os.path.join(root, file)
        rutas_archivos.append(ruta_completa)

# Crear un DataFrame de ejemplo con rutas de imágenes
data = {'imagen': rutas_archivos}
df = pd.DataFrame(data)

# Función para obtener la carpeta de una ruta
def obtener_carpeta(ruta):
    return os.path.dirname(ruta)

# Función para obtener el nombre de la imagen sin la extensión
def obtener_nombre_imagen(ruta):
    return os.path.splitext(os.path.basename(ruta))[0]

# Agregar una columna 'carpeta' al DataFrame
df['carpeta'] = df['imagen'].apply(obtener_carpeta)



#ARREGLAR carpeta 0 i 1
df['carpeta'] = df['carpeta'].map({'spiral2/training\total_training_healthy_negro': 0, 'spiral2/training\total_training_parkinson_negro': 1})
# Mostrar el DataFrame resultante
print(df.shape)
print('ARREGLAR CARPETA! ')
# Out:
# (8640, 2)
# ARREGLAR CARPETA!

# %%
df.shape
# Out:
# (36, 2)
