# %%
import pandas as pd

# %%
df1 = pd.read_excel('T1.xlsx', sheet_name=None)
df1
# Out:
# {'h1':      PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  145          146         0       2
#  146          147         1       3
#  147          148         0       3
#  148          149         0       2
#  149          150         0       2
#
#                                                    Name     Sex   Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    male  22.0      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#  4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df2 = pd.read_csv('T2.csv')
df2
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0            301         1       3  Kelly, Miss. Anna Katherine "Annie Kate"
# 1            302         1       3                        McCoy, Mr. Bernard
# 2            303         0       3           Johnson, Mr. William Cahoone Jr
# 3            304         1       2                       Keane, Miss. Nora A
# 4            305         0       3         Williams, Mr. Howard Hugh "Harry"
# ..           ...       ...     ...                                       ...
# 145          446         1       1                 Dodge, Master. Washington
# 146          447         1       2         Mellinger, Miss. Madeleine Violet
# 147          448         1       1               Seward, Mr. Frederic Kimber
# 148          449         1       3            Baclini, Miss. Marie Catherine
# 149          450         1       1            Peuchen, Major. Arthur Godfrey
#
# ...

# %%
df3=pd.read_xml('T3.xml')
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            451         0       2
# 1            452         0       3
# 2            453         0       1
# 3            454         1       1
# 4            455         0       3
# ..           ...       ...     ...
# 145          596         0       3
# 146          597         1       2
# 147          598         0       3
# 148          599         0       3
# 149          600         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                           West, Mr. Edwy Arthur    male  36.0      1      2
# 1                 Hagland, Mr. Ingvald Olai Olsen    male   NaN      1      0
# 2                 Foreman, Mr. Benjamin Laventall    male  30.0      0      0
# 3                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 4                             Peduzzi, Mr. Joseph    male   NaN      0      0
# ...

# %%
df4=pd.read_csv('T4.csv', sep=";", decimal=",")
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0            601         1       2
# 1            602         0       3
# 2            603         0       1
# 3            604         0       3
# 4            605         1       1
# ..           ...       ...     ...
# 144          745         1       3
# 145          746         0       1
# 146          747         0       3
# 147          748         1       2
# 148          749         0       1
#
#                                                   Name     Sex  Age  SibSp  \
# 0    Jacobsohn; Mrs. Sidney Samuel (Amy Frances Chr...  female   24      2
# 1                                 Slabenoff; Mr. Petco    male  NaN      0
# 2                            Harrington; Mr. Charles H    male  NaN      0
# 3                            Torber; Mr. Ernst William    male   44      0
# 4                      Homer; Mr. Harry ("Mr E Haven")    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df5 = pd.read_csv("T5.txt", sep = "\t")
df5
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0            750         0       3                   Connaghton, Mr. Michael
# 1            751         1       2                         Wells, Miss. Joan
# 2            752         1       3                       Moor, Master. Meier
# 3            753         0       3          Vande Velde, Mr. Johannes Joseph
# 4            754         0       3                        Jonkoff, Mr. Lalio
# ..           ...       ...     ...                                       ...
# 137          887         0       2                     Montvila, Rev. Juozas
# 138          888         1       1              Graham, Miss. Margaret Edith
# 139          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 140          890         1       1                     Behr, Mr. Karl Howell
# 141          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df6 = pd.read_csv("T6")
df6
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df = pd.concat([df1['h1'], df1['h2'],df2,df3,df4,df5,df6])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 1.- tipo de características (columnas)

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass        SibSp        Parch
# count  1309.000000  891.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    0.383838     2.294882     0.498854     0.385027
# std     378.020061    0.486592     0.837836     1.041658     0.865560
# min       1.000000    0.000000     1.000000     0.000000     0.000000
# 25%     328.000000    0.000000     2.000000     0.000000     0.000000
# 50%     655.000000    0.000000     3.000000     0.000000     0.000000
# 75%     982.000000    1.000000     3.000000     1.000000     0.000000
# max    1309.000000    1.000000     3.000000     8.000000     9.000000

# %%
# 2.- 5 primeros elementos

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171     7.25   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282    7.925   NaN        S
# 3      0            113803     53.1  C123        S
# 4      0            373450     8.05   NaN        S

# %%
# 3.- una muestra de 10 registros

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# 4.- Indexar por ID_Pasajero

# %%
df.set_index('PassengerId',inplace=True)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# 5.- Verificar datos nulos

# %%
df.isnull().sum()
# Out:
# Survived     418
# Pclass         0
# Name           0
# Sex            0
# Age          263
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Cabin       1014
# Embarked       2
# dtype: int64

# %%
# 6.- Verificar datos duplicados

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# 7.- Separar y eliminar del df la columna target

# %%
survived = df['Survived']
survived
# Out:
# PassengerId
# 1       0.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       0.0
#        ...
# 1305    NaN
# 1306    NaN
# 1307    NaN
# 1308    NaN
# 1309    NaN
# Name: Survived, Length: 1309, dtype: float64

# %%
df_survived = df.drop('Survived', axis=1)

# %%
df_survived
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# ...             ...                                                ...
# 1305              3                                 Spector, Mr. Woolf
# 1306              1                       Oliva y Ocana, Dona. Fermina
# 1307              3                       Saether, Mr. Simon Sivertsen
# 1308              3                                Ware, Mr. Frederick
# 1309              3                           Peter, Master. Michael J
#
#                 Sex   Age  SibSp  Parch              Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
# 8.- Eliminar columnas categoricas no importantes

# %%
df_survived.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df_survived
# Out:
#              Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                 3    male  22.0      1      0     7.25        S
# 2                 1  female  38.0      1      0  71.2833        C
# 3                 3  female  26.0      0      0    7.925        S
# 4                 1  female  35.0      1      0     53.1        S
# 5                 3    male  35.0      0      0     8.05        S
# ...             ...     ...   ...    ...    ...      ...      ...
# 1305              3    male   NaN      0      0     8.05        S
# 1306              1  female  39.0      0      0    108.9        C
# 1307              3    male  38.5      0      0     7.25        S
# 1308              3    male   NaN      0      0     8.05        S
# 1309              3    male   NaN      1      1  22.3583        C
#
# [1309 rows x 7 columns]
